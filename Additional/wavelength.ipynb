# %%
import math
base = 10000
theta_min = 1.0 / base
max_wavelen = 2 * math.pi / theta_min  # ~62831.853
max_wavelen
# Out:
# 62831.85307179586

# %%
# Your RoPE setup
base = 10000.0
d = 32  # embedding dimension

# Max dimension pair index
i_max = d // 2 - 1  # 15

# Lowest frequency theta_i
theta_min = base ** (-2.0 * i_max / d)  # 10000^(-30/32)

# Max wavelength (tokens per full rotation)
wavelength_max = 2 * math.pi / theta_min

print(f"theta_min: {theta_min:.6f}")
print(f"max wavelength: {wavelength_max:.0f}")
# Out:
# theta_min: 0.000178
# max wavelength: 35333
